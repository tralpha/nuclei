# %%
from dataset import reader, annotate
# %matplotlib inline
# Out:
# @common.py:
# 	set random seed
# 		SEED=35202
# 	set cuda environment
# 		torch.__version__              = 0.4.0a0+694bee1
# 		torch.version.cuda             = 9.1
# 		torch.backends.cudnn.version() = 7005
# 		os['CUDA_VISIBLE_DEVICES']     = None
# 		torch.cuda.device_count()      = 1
# 		torch.cuda.current_device()    = 0

# %%
reader.run_check_dataset_reader()
# Out:
# 	time = 0.00 min
# 	num_ids = 670
#
# 	time = 0.00 min
# 	num_ids = 43
#
# n=0------------------------------------------
# meta :  274    whiteblack
# Name: im_type, dtype: object
# image_shape :  (256, 256, 3)
# new_image_shape :  (256, 256, 3)
# > /Users/ralphtigoumo/Documents/kaggle/nuclei/20180306/build/mask-rcnn-resnet50-ver-01.a/dataset/reader.py(375)run_check_dataset_reader()
#     373     # sampler = RandomSampler(dataset)
#     374
# --> 375     for n in iter(sampler):
#     376         #for n in range(10):
#     377         #n=0
#
# ipdb> input.shape
# torch.Size([3, 256, 256])
# ipdb> input
#
# ( 0 ,.,.) =
#   0.0078  0.0078  0.0078  ...   0.0078  0.0078  0.0078
#   0.0078  0.0078  0.0078  ...   0.0078  0.0078  0.0078
#   0.0078  0.0078  0.0078  ...   0.0078  0.0078  0.0078
#            ...             ⋱             ...
#   0.0118  0.0078  0.0078  ...   0.0118  0.0118  0.0078
#   0.0078  0.0078  0.0078  ...   0.0118  0.0118  0.0118
# ...

# %%
annotate.run_make_train_annotation()
